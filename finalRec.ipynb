# %%
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import RegexpTokenizer
import re
import string
import random
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt
from textblob import TextBlob
from sklearn.metrics.pairwise import cosine_similarity
# %matplotlib inline

# %%
df = pd.read_csv("Book1.csv")
df=df.dropna(subset=['Desc'])
df.shape
df.reset_index(level = 0, inplace = True)

# %%
x = df.set_index('title').genres.str.split(r'|', expand=True).stack().reset_index(level=1, drop=True).to_frame('genre');  pd.get_dummies(x, prefix='g', columns=['genre']).groupby(level=0).sum()
# Out:
#                                                     g_19th Century  \
# title
# 1984                                                             0
# A Clash of Kings                                                 0
# A Clockwork Orange                                               0
# A Confederacy of Dunces                                          0
# A Farewell to Arms                                               0
# ...                                                            ...
# Where the Wild Things Are                                        0
# White Oleander                                                   0
# Wicked: The Life and Times of the Wicked Witch ...               0
# Winnie-the-Pooh                                                  0
# Wuthering Heights                                                0
#
#                                                     g_20th Century  \
# title
# 1984                                                             0
# A Clash of Kings                                                 0
# A Clockwork Orange                                               0
# A Confederacy of Dunces                                          0
# A Farewell to Arms                                               0
# ...                                                            ...
# Where the Wild Things Are                                        0
# White Oleander                                                   0
# Wicked: The Life and Times of the Wicked Witch ...               0
# Winnie-the-Pooh                                                  0
# Wuthering Heights                                                0
#
#                                                     g_Academic  g_Adult  \
# title
# 1984                                                         0        0
# A Clash of Kings                                             0        0
# A Clockwork Orange                                           0        0
# A Confederacy of Dunces                                      0        0
# A Farewell to Arms                                           0        0
# ...                                                        ...      ...
# Where the Wild Things Are                                    0        0
# White Oleander                                               0        0
# Wicked: The Life and Times of the Wicked Witch ...           0        1
# Winnie-the-Pooh                                              0        0
# Wuthering Heights                                            0        0
#
#                                                     g_Adult Fiction  \
# title
# 1984                                                              0
# A Clash of Kings                                                  0
# A Clockwork Orange                                                0
# A Confederacy of Dunces                                           0
# A Farewell to Arms                                                0
# ...                                                             ...
# Where the Wild Things Are                                         0
# White Oleander                                                    0
# Wicked: The Life and Times of the Wicked Witch ...                0
# Winnie-the-Pooh                                                   0
# Wuthering Heights                                                 0
#
#                                                     g_Adventure  g_Africa  \
# title
# 1984                                                          0         0
# A Clash of Kings                                              0         0
# A Clockwork Orange                                            0         0
# A Confederacy of Dunces                                       0         0
# A Farewell to Arms                                            0         0
# ...                                                         ...       ...
# Where the Wild Things Are                                     0         0
# White Oleander                                                0         0
# Wicked: The Life and Times of the Wicked Witch ...            0         0
# Winnie-the-Pooh                                               0         0
# Wuthering Heights                                             0         0
#
#                                                     g_African American  \
# title
# 1984                                                                 0
# A Clash of Kings                                                     0
# A Clockwork Orange                                                   0
# A Confederacy of Dunces                                              0
# A Farewell to Arms                                                   0
# ...                                                                ...
# Where the Wild Things Are                                            0
# White Oleander                                                       0
# Wicked: The Life and Times of the Wicked Witch ...                   0
# Winnie-the-Pooh                                                      0
# Wuthering Heights                                                    0
#
#                                                     g_American  g_Angels  ...  \
# title                                                                     ...
# 1984                                                         0         0  ...
# A Clash of Kings                                             0         0  ...
# A Clockwork Orange                                           0         0  ...
# A Confederacy of Dunces                                      0         0  ...
# A Farewell to Arms                                           0         0  ...
# ...                                                        ...       ...  ...
# Where the Wild Things Are                                    0         0  ...
# White Oleander                                               0         0  ...
# Wicked: The Life and Times of the Wicked Witch ...           0         0  ...
# Winnie-the-Pooh                                              0         0  ...
# Wuthering Heights                                            0         0  ...
#
#                                                     g_True Crime  \
# title
# 1984                                                           0
# A Clash of Kings                                               0
# A Clockwork Orange                                             0
# A Confederacy of Dunces                                        0
# A Farewell to Arms                                             0
# ...                                                          ...
# Where the Wild Things Are                                      0
# White Oleander                                                 0
# Wicked: The Life and Times of the Wicked Witch ...             0
# Winnie-the-Pooh                                                0
# Wuthering Heights                                              0
#
#                                                     g_Urban Fantasy  \
# title
# 1984                                                              0
# A Clash of Kings                                                  0
# A Clockwork Orange                                                0
# A Confederacy of Dunces                                           0
# A Farewell to Arms                                                0
# ...                                                             ...
# Where the Wild Things Are                                         0
# White Oleander                                                    0
# Wicked: The Life and Times of the Wicked Witch ...                0
# Winnie-the-Pooh                                                   0
# Wuthering Heights                                                 0
#
#                                                     g_Vampires  g_War  \
# title
# 1984                                                         0      0
# A Clash of Kings                                             0      0
# A Clockwork Orange                                           0      0
# A Confederacy of Dunces                                      0      0
# A Farewell to Arms                                           0      1
# ...                                                        ...    ...
# Where the Wild Things Are                                    0      0
# White Oleander                                               0      0
# Wicked: The Life and Times of the Wicked Witch ...           0      0
# Winnie-the-Pooh                                              0      0
# Wuthering Heights                                            0      0
#
#                                                     g_Werewolves  g_Westerns  \
# title
# 1984                                                           0           0
# A Clash of Kings                                               0           0
# A Clockwork Orange                                             0           0
# A Confederacy of Dunces                                        0           0
# A Farewell to Arms                                             0           0
# ...                                                          ...         ...
# Where the Wild Things Are                                      0           0
# White Oleander                                                 0           0
# Wicked: The Life and Times of the Wicked Witch ...             0           0
# Winnie-the-Pooh                                                0           0
# Wuthering Heights                                              0           0
#
#                                                     g_Womens Fiction  \
# title
# 1984                                                               0
# A Clash of Kings                                                   0
# A Clockwork Orange                                                 0
# A Confederacy of Dunces                                            0
# A Farewell to Arms                                                 0
# ...                                                              ...
# Where the Wild Things Are                                          0
# White Oleander                                                     1
# Wicked: The Life and Times of the Wicked Witch ...                 0
# Winnie-the-Pooh                                                    0
# Wuthering Heights                                                  0
#
#                                                     g_World War II  g_Writing  \
# title
# 1984                                                             0          0
# A Clash of Kings                                                 0          0
# A Clockwork Orange                                               0          0
# A Confederacy of Dunces                                          0          0
# A Farewell to Arms                                               0          0
# ...                                                            ...        ...
# Where the Wild Things Are                                        0          0
# White Oleander                                                   0          0
# Wicked: The Life and Times of the Wicked Witch ...               0          0
# Winnie-the-Pooh                                                  0          0
# Wuthering Heights                                                0          0
#
#                                                     g_Young Adult
# title
# 1984                                                            0
# A Clash of Kings                                                0
# A Clockwork Orange                                              0
# A Confederacy of Dunces                                         0
# A Farewell to Arms                                              0
# ...                                                           ...
# Where the Wild Things Are                                       0
# White Oleander                                                  0
# Wicked: The Life and Times of the Wicked Witch ...              0
# Winnie-the-Pooh                                                 0
# Wuthering Heights                                               0
#
# [290 rows x 132 columns]

# %%
# Function for removing NonAscii characters
def _removeNonAscii(s):
    return "".join(i for i in s if  ord(i)<128)

# Function for converting into lower case
def make_lower_case(text):
    return text.lower()

# Function for removing stop words
def remove_stop_words(text):
    text = text.split()
    stops = set(stopwords.words("english"))
    text = [w for w in text if not w in stops]
    text = " ".join(text)
    return text

# Function for removing punctuation
def remove_punctuation(text):
    tokenizer = RegexpTokenizer(r'\w+')
    text = tokenizer.tokenize(text)
    text = " ".join(text)
    return text

# Function for removing the html tags
def remove_html(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)

# Applying all the functions in description and storing as a cleaned_desc
df['cleaned_desc'] = df['Desc'].apply(_removeNonAscii)
df['cleaned_desc'] = df.cleaned_desc.apply(func = make_lower_case)
df['cleaned_desc'] = df.cleaned_desc.apply(func = remove_stop_words)
df['cleaned_desc'] = df.cleaned_desc.apply(func=remove_punctuation)
df['cleaned_desc'] = df.cleaned_desc.apply(func=remove_html)

# %%
df2= pd.merge(df,x,on='title')

# %%
def recommends(title, genre):
    
    global rec
    # Matching the genre with the dataset and reset the index
    data = df2.loc[df2['genre'] == genre]  
    data.reset_index(level = 0, inplace = True) 
  
    # Convert the index into series
    indices = pd.Series(data.index, index = data['title'])
    
    #Converting the book description into vectors and used bigram
    tf = TfidfVectorizer(analyzer='word', ngram_range=(2, 2), min_df = 1, stop_words='english')
    tfidf_matrix = tf.fit_transform(data['cleaned_desc'])
    
    # Calculating the similarity measures based on Cosine Similarity
    sg = cosine_similarity(tfidf_matrix, tfidf_matrix)
    
    # Get the index corresponding to original_title
       
    idx = indices[title]# Get the pairwsie similarity scores 
    sig = list(enumerate(sg[idx]))# Sort the books
    sig = sorted(sig, key=lambda x: x[1], reverse=True)# Scores of the 5 most similar books 
    sig = sig[1:6]# Book indicies
    movie_indices = [i[0] for i in sig]
   
    # Top 5 book recommendation
    rec = data[['title', 'image_url']].iloc[movie_indices]
    
    # It reads the top 5 recommend book url and print the images
    
    for i in rec['image_url']:
        response = requests.get(i)
        img = Image.open(BytesIO(response.content))
        plt.figure()
        print(plt.imshow(img))

# %%
recommends("The Hunger Games", "Fiction")
# Out:
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)

# %%
recommends("Marked", "Fiction")
# Out:
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)

# %%
recommends("It", "Horror")
# Out:
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
